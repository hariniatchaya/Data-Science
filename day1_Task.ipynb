# %%
#Variables and Data Types
name = "Harini"
age = 20
cgpa = 7.9
is_engineering_student = True
skills = ["Python","Excel","SQL"]
print("Student Information")
print("-"*30)

print(f"Name:{name}")
print(f"Age:{age}")
print(f"CGPA:{cgpa}")
print(f"Engineering Student:{is_engineering_student}")
print(f"Skills:{skills}")

print("\nData Type")
print(type(name))
print(type(age))
print(type(cgpa))
print(type(is_engineering_student))
print(type(skills))
# Out:
# Student Information
# ------------------------------
# Name:Harini
# Age:20
# CGPA:7.9
# Engineering Student:True
# Skills:['Python', 'Excel', 'SQL']
#
# Data Type
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'list'>

# %%
# User Input Program
name = input("Enter your name: ")
age = int(input("Enter your age: "))
city = input("Enter your city: ")

print("/nUser Profile")
print("-" * 30)
print(f"Name : {name}")
print(f"Age : {age}")
print(f"City : {city}")

years_to_25 = 25 - age
if years_to_25 > 0:
  print(f"You will turn 25 in {years_to_25} years.")
else:
  print("You are already 25 or older.")
# Out:
# Enter your name: Harini
# Enter your age: 21
# Enter your city: Coimbatore
# /nUser Profile
# ------------------------------
# Name : Harini
# Age : 21
# City : Coimbatore
# You will turn 25 in 4 years.

# %%
# User Input Program
name = input("Enter your name: ")
age = int(input("Enter your age: "))
city = input("Enter your city: ")

print("/nUser Profile")
print("-" * 30)
print(f"Name : {name}")
print(f"Age : {age}")
print(f"City : {city}")

years_to_25 = 25 - age
if years_to_25 > 0:
  print(f"You will turn 25 in {years_to_25} years.")
else:
  print("You are already 25 or older.")
# Out:
# Enter your name: Atchaya
# Enter your age: 29
# Enter your city: Pune
# /nUser Profile
# ------------------------------
# Name : Atchaya
# Age : 29
# City : Pune
# You are already 25 or older.

# %%
#Arithmetic OPeration Calculator
num1 = float(input("Enter first number:"))
num2 = float(input("Enter second number:"))

print("/nREsults")
print("-" * 30)

print("Addition =",num1 + num2)
print("Subtraction=",num1 - num2)
print("Multiplication=",num1 * num2)

if num2 != 0:
   print("Division=",num1 / num2)
else:
  print("Division not possible(cannot division by zero)")

print("Modulus=",num1 % num2)
print("Power=",num1 ** num2)
# Out:
# Enter first number:3
# Enter second number:5
# /nREsults
# ------------------------------
# Addition = 8.0
# Subtraction= -2.0
# Multiplication= 15.0
# Division= 0.6
# Modulus= 3.0
# Power= 243.0

# %%
#Student Mark calculator
student_name = input("Enter Student Name:")

mark1 = float(input("Enter Mark1:"))
mark2 = float(input("Enter Mark2:"))
mark3 = float(input("Enter Mark3:"))

total = mark1+mark2+mark3
average = total / 3

print("\nStudent Name:",student_name)
print("Total Mark:",total)
print("Average Mark:",average)

if average >= 90:
  grade = "A"
elif average >= 75:
  grade = "B"
elif average >= 60:
  grade = "c"
else:
  grade = "D"
print("Grade:",grade)
# Out:
# Enter Student Name:Sakthi
# Enter Mark1:80
# Enter Mark2:85
# Enter Mark3:90
#
# Student Name: Sakthi
# Total Mark: 255.0
# Average Mark: 85.0
# Grade: B
